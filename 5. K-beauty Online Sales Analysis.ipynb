# %%
# 5.1강 국가통계포털 데이터셋 소개 (3:51)

# %% [markdown]
# ***

# %%
# 5.2강 데이터셋 로드하기(09:17)

# %% [markdown]
# ### **1. Online shopping overseas direct sales by country (continent)/product group**

# %% [markdown]
# - KOSIS 국가통계포털 : [https://kosis.kr/index/index.do](https://kosis.kr/index/index.do)

# %% [markdown]
# - [국가통계포털 - 주제별통계 - 도소매/서비스 - 온라인쇼핑동향조사 - 국가(대륙)별/상품군별 온라인쇼핑 해외직접판매액](https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1KE10081&vw_cd=MT_ZTITLE&list_id=O_14&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_ZTITLE&path=%252FstatisticsList%252FstatisticsListIndex.do)

# %% [markdown]
#  -  생활정보사이트: 더외식  <br>
#     **e : 추정치  <br> p : 잠정치  <br> - : 자료없음  <br> ... : 미상자료  <br> x : 비밀보호  <br> ▽ : 시계열 불연속  <br> (단위: 백만원)**

# %% [markdown]
# ###### **1.1 K-Beauty 는 성장하고 있을까? 해외 직접판매를 한다면 어느 국가로 판매전략을 세우면 좋을까?**

# %% [markdown]
# ### **2. Import Required Libraries**
# [필요 라이브러리 가져오기]

# %%
# 라이브러리 로드

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 시각화를 위한 폰트 설정

import os

os.name

if os.name  == "nt":
    sns.set(font = "Malgun Gothic") # 윈도우용
else:
    sns.set(font = "AppleGothic") # 맥용

# %%
# 레티나 설정을 해주면 글씨가 좀 더 선명하게 보입니다.
#폰트의 주변이 흐릿하게 보이는 것을 방지합니다.

# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### **3. Load data**
# [데이터 로드하기]

# %%
df_raw = pd.read_csv("datadori/국가_대륙_별_상품군별_온라인쇼핑_해외직접판매액_20230124190820.CSV", encoding = "cp949")
df_raw
# Out:
#     국가(대륙)별          상품군별   판매유형별  2017.1/4  2017.2/4  2017.3/4  2017.4/4  \
# 0        합계            합계       계    839944    581349    755101    858240
# 1        합계            합계     면세점    673803    441213    610630    677884
# 2        합계            합계  면세점 이외    166141    140136    144471    180356
# 3        합계    컴퓨터 및 주변기기       계      2645      2072      2032      2158
# 4        합계    컴퓨터 및 주변기기     면세점         5         3         5         1
# ..      ...           ...     ...       ...       ...       ...       ...
# 445      기타  생활용품 및 자동차용품     면세점         0         0         0         0
# 446      기타  생활용품 및 자동차용품  면세점 이외       662       601       581       634
# 447      기타           기 타       계       887       747       816      1101
# 448      기타           기 타     면세점         2         0        82       266
# 449      기타           기 타  면세점 이외       885       747       734       835
#
#      2018.1/4  2018.2/4  2018.3/4  ...  2020.2/4  2020.3/4  2020.4/4  \
# ...

# %%
df_raw.shape
# Out:
# (450, 26)

# %%
# 국가(대륙)별" 데이터 빈도수 세기
df_raw["국가(대륙)별"].value_counts()
# Out:
# 합계            45
# 미국            45
# 중국            45
# 일본            45
# 아세안(ASEAN)    45
# 유럽연합(EU)      45
# 중동            45
# 중남미           45
# 대양주           45
# 기타            45
# Name: 국가(대륙)별, dtype: int64

# %%
# 미국 데이터만 따로 보기
df_raw[df_raw["국가(대륙)별"] == "미국"]
# Out:
#    국가(대륙)별          상품군별   판매유형별  2017.1/4  2017.2/4  2017.3/4  2017.4/4  \
# 45      미국            합계       계     46662     41385     42331     53209
# 46      미국            합계     면세점      8160      9190      9469     12177
# 47      미국            합계  면세점 이외     38502     32195     32862     41032
# 48      미국    컴퓨터 및 주변기기       계      1081       970       802       854
# 49      미국    컴퓨터 및 주변기기     면세점         0         0         0         0
# 50      미국    컴퓨터 및 주변기기  면세점 이외      1081       970       802       854
# 51      미국    가전·전자·통신기기       계      2895      2513      2631      2394
# 52      미국    가전·전자·통신기기     면세점        18        23        29        32
# 53      미국    가전·전자·통신기기  면세점 이외      2877      2490      2602      2362
# 54      미국         소프트웨어       계        68       100       123       125
# 55      미국         소프트웨어     면세점         0         0         0         0
# 56      미국         소프트웨어  면세점 이외        68       100       123       125
# ...

# %% [markdown]
# ***

# %%
# 5.3강 데이터 전처리 - tidy data 만들기 (06:33)

# %% [markdown]
# ### **4. Create tidy data for analysis and visualization**
# [분석과 시각화를 위한 tidy data 만들기]

# %% [markdown]
# - [https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)

# %%
df_raw.melt?
# Out:
# Signature:
# df_raw.melt(
#     id_vars=None,
#     value_vars=None,
#     var_name=None,
#     value_name='value',
#     col_level: 'Level | None' = None,
#     ignore_index: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
# This function is useful to massage a DataFrame into a format where one
# or more columns are identifier variables (`id_vars`), while all other
# columns, considered measured variables (`value_vars`), are "unpivoted" to
# the row axis, leaving just two non-identifier columns, 'variable' and
# 'value'.
#
# Parameters
# ----------
# id_vars : tuple, list, or ndarray, optional
#     Column(s) to use as identifier variables.
# value_vars : tuple, list, or ndarray, optional
#     Column(s) to unpivot. If not specified, uses all columns that
#     are not set as `id_vars`.
# var_name : scalar
#     Name to use for the 'variable' column. If None it uses
# ...

# %%
# 컬럼명이 잘 생각이 안날때는

df_raw.columns
# Out:
# Index(['국가(대륙)별', '상품군별', '판매유형별', '2017.1/4', '2017.2/4', '2017.3/4',
#        '2017.4/4', '2018.1/4', '2018.2/4', '2018.3/4', '2018.4/4', '2019.1/4',
#        '2019.2/4', '2019.3/4', '2019.4/4', '2020.1/4', '2020.2/4', '2020.3/4',
#        '2020.4/4', '2021.1/4', '2021.2/4', '2021.3/4', '2021.4/4', '2022.1/4',
#        '2022.2/4', '2022.3/4 p)'],
#       dtype='object')

# %%
df_raw.values
# Out:
# array([['합계', '합계', '계', ..., 567581, 505954, 399881],
#        ['합계', '합계', '면세점', ..., 363520, 300602, 211727],
#        ['합계', '합계', '면세점 이외', ..., 204061, 205352, 188154],
#        ...,
#        ['기타', '기 타', '계', ..., 2325, 725, 288],
#        ['기타', '기 타', '면세점', ..., 0, 0, 0],
#        ['기타', '기 타', '면세점 이외', ..., 2325, 725, 288]], dtype=object)

# %%
df_raw.melt(id_vars=["국가(대륙)별", "상품군별", "판매유형별"])

# 나머지 컬럼값(날짜 등)이 varialbe 로 행으로 표시됨
# df_raw.values 에 해당하는 값들을 value 의 행으로 표시됨
# Out:
#       국가(대륙)별          상품군별   판매유형별     variable   value
# 0          합계            합계       계     2017.1/4  839944
# 1          합계            합계     면세점     2017.1/4  673803
# 2          합계            합계  면세점 이외     2017.1/4  166141
# 3          합계    컴퓨터 및 주변기기       계     2017.1/4    2645
# 4          합계    컴퓨터 및 주변기기     면세점     2017.1/4       5
# ...       ...           ...     ...          ...     ...
# 10345      기타  생활용품 및 자동차용품     면세점  2022.3/4 p)       0
# 10346      기타  생활용품 및 자동차용품  면세점 이외  2022.3/4 p)      83
# 10347      기타           기 타       계  2022.3/4 p)     288
# 10348      기타           기 타     면세점  2022.3/4 p)       0
# 10349      기타           기 타  면세점 이외  2022.3/4 p)     288
#
# [10350 rows x 5 columns]

# %%
# id_vars 에 지정되지 않은 컬럼값들은 
# 자동으로 value_vars 에 지정되는 것을 알 수 있음

# %%
# variable 을 "기간"으로 명칭 바꾸기
# value 을 "백만원"으로 명칭 바꾸기

df = df_raw.melt(id_vars=["국가(대륙)별", "상품군별", "판매유형별"],
            var_name="기간", value_name="백만원")
df
# Out:
#       국가(대륙)별          상품군별   판매유형별           기간     백만원
# 0          합계            합계       계     2017.1/4  839944
# 1          합계            합계     면세점     2017.1/4  673803
# 2          합계            합계  면세점 이외     2017.1/4  166141
# 3          합계    컴퓨터 및 주변기기       계     2017.1/4    2645
# 4          합계    컴퓨터 및 주변기기     면세점     2017.1/4       5
# ...       ...           ...     ...          ...     ...
# 10345      기타  생활용품 및 자동차용품     면세점  2022.3/4 p)       0
# 10346      기타  생활용품 및 자동차용품  면세점 이외  2022.3/4 p)      83
# 10347      기타           기 타       계  2022.3/4 p)     288
# 10348      기타           기 타     면세점  2022.3/4 p)       0
# 10349      기타           기 타  면세점 이외  2022.3/4 p)     288
#
# [10350 rows x 5 columns]

# %%
df.shape
# Out:
# (10350, 5)

# %%
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간     백만원
# 0      합계          합계       계  2017.1/4  839944
# 1      합계          합계     면세점  2017.1/4  673803
# 2      합계          합계  면세점 이외  2017.1/4  166141
# 3      합계  컴퓨터 및 주변기기       계  2017.1/4    2645
# 4      합계  컴퓨터 및 주변기기     면세점  2017.1/4       5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10350 entries, 0 to 10349
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  10350 non-null  object
#  1   상품군별     10350 non-null  object
#  2   판매유형별    10350 non-null  object
#  3   기간       10350 non-null  object
#  4   백만원      10350 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 404.4+ KB

# %%
# 대부분 object 타입이므로 데이터 전처리 필요!

# 기간에서 연도와 분기를 분리하고
# 백만원에서 금액데이터를 수치로 바꿔주어야 함.

# %% [markdown]
# ***

# %%
# 5.4강 데이터 전처리 - 문자열 분리하고 데이터 타입 변경하기 (13:29)

# %% [markdown]
# ### **5. data preprocessing**
# [데이터 전처리]

# %% [markdown]
# #### **5.1 Separating Years from Periods**
# [기간에서 연도를 분리하기]

# %%
df["기간"]
# Out:
# 0           2017.1/4
# 1           2017.1/4
# 2           2017.1/4
# 3           2017.1/4
# 4           2017.1/4
#             ...
# 10345    2022.3/4 p)
# 10346    2022.3/4 p)
# 10347    2022.3/4 p)
# 10348    2022.3/4 p)
# 10349    2022.3/4 p)
# Name: 기간, Length: 10350, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# #### "2022.3/4 p)" 쪼개기

# %% [markdown]
# [파이썬 split 구분자 여러개 있을 때 분리하기](https://codingdog.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-split-%EA%B5%AC%EB%B6%84%EC%9E%90-%EC%97%AC%EB%9F%AC%EA%B0%9C-%EC%9E%88%EC%9D%84-%EB%95%8C-%EC%9E%98-%EB%B6%84%EB%A6%AC%ED%95%B4-%EB%B4%85%EC%8B%9C%EB%8B%A4)

# %% [markdown]
# [문자열 split 여러번 적용 1 ](https://gomming.tistory.com/18)

# %% [markdown]
# [re.split() ](https://pynative.com/python-regex-split/)

# %% [markdown]
# [문자열 패턴으로 분리하기 (split)](https://wikidocs.net/80574)

# %%
# "2022.3/4 p)".split() 의 0번째 인덱스

"2022.3/4 p)".split()
# Out:
# ['2022.3/4', 'p)']

# %%
s = "2022.3/4 p)"
s1 = s.replace("."," ")
print(s1)
# Out:
# 2022 3/4 p)

# %%
import re

s = "2022.3/4 p)"
s2 = re.split(r"[., ]", s)
print(s2)
# Out:
# ['2022', '3/4', 'p)']

# %%
s2[0]
# Out:
# '2022'

# %%
# 앗 뒤에서 적용안되는 구먼

# %% [markdown]
# ---

# %% [markdown]
# ***

# %%
# 기간이 "2022.1/4 p" 이렇게 뜨시는 분들은

# df["분기"] = list(map(lambda x : int(x.split(".")[1].split()[0].split("/")[0]), df["기간"])) 하시면 됩니다.

# (1) "." 을 기준으로 split하고 (["2022", "1/4 p"]) 1번째 인덱스를 취함 -> "1/4 p"

# (2) " " 을 기준으로 split하고 (["1/4", "p"]) 0번째 인덱스를 취함 -> "1/4"

# (3) "/"을 기준으로 split하고 (["1", "4"]) 0번째 인덱스를 취함

# (4) "1"에 int() 형변환 함수를 씌워 int64형으로 변환

# %%
df["분기"] = list(map(lambda x : int(x.split(".")[1].split()[0].split("/")[0]),
                    df["기간"]))

# %%
"2022.3/4 p)".split(".")
# Out:
# ['2022', '3/4 p)']

# %%
"2022.3/4 p)".split(".")[0]
# Out:
# '2022'

# %%
"2022.3/4 p)".split(".")[1]
# Out:
# '3/4 p)'

# %%
type("2022.3/4 p)".split(".")[0])
# Out:
# str

# %%
int("2022.3/4 p)".split(".")[0])
# Out:
# 2022

# %% [markdown]
# ***

# %% [markdown]
# ***

# %%
#  다시

# %%
int("2022.3/4 p)".split(".")[0])
# Out:
# 2022

# %%
df["기간"].map?
# Out:
# Init signature: map(self, /, *args, **kwargs)
# Docstring:
# map(func, *iterables) --> map object
#
# Make an iterator that computes the function using arguments from
# each of the iterables.  Stops when the shortest iterable is exhausted.
# Type:           type
# Subclasses:

# %%
df["기간"].map

# %%
df["기간"].map(lambda x : x.split(".")[0])

# dtype 이 object로 나오므로 우리가 원하는 int type 으로 바꿔줘야함
# Out:
# 0        2017
# 1        2017
# 2        2017
# 3        2017
# 4        2017
#          ...
# 10345    2022
# 10346    2022
# 10347    2022
# 10348    2022
# 10349    2022
# Name: 기간, Length: 10350, dtype: object

# %%
df["기간"].map(lambda x : int(x.split(".")[0]))
# Out:
# 0        2017
# 1        2017
# 2        2017
# 3        2017
# 4        2017
#          ...
# 10345    2022
# 10346    2022
# 10347    2022
# 10348    2022
# 10349    2022
# Name: 기간, Length: 10350, dtype: int64

# %%
# 위의 결과를 "연도"라는 새로운 컬럼에  넣는다

df["연도"] = df["기간"].map(lambda x : int(x.split(".")[0]))
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간     백만원  분기    연도
# 0      합계          합계       계  2017.1/4  839944   1  2017
# 1      합계          합계     면세점  2017.1/4  673803   1  2017
# 2      합계          합계  면세점 이외  2017.1/4  166141   1  2017
# 3      합계  컴퓨터 및 주변기기       계  2017.1/4    2645   1  2017
# 4      합계  컴퓨터 및 주변기기     면세점  2017.1/4       5   1  2017

# %%
# 기간이 "2022.1/4 p" 이렇게 뜨시는 분들은

# df["분기"] = list(map(lambda x : int(x.split(".")[1].split()[0].split("/")[0]), df["기간"])) 하시면 됩니다.

# (1) "." 을 기준으로 split하고 (["2022", "1/4 p"]) 1번째 인덱스를 취함 -> "1/4 p"

# (2) " " 을 기준으로 split하고 (["1/4", "p"]) 0번째 인덱스를 취함 -> "1/4"

# (3) "/"을 기준으로 split하고 (["1", "4"]) 0번째 인덱스를 취함

# (4) "1"에 int() 형변환 함수를 씌워 int64형으로 변환

# %%
# 기간에서 분기만 분리하기

"2022.3/4 p)".split(".")[1]
# Out:
# '3/4 p)'

# %%
"2022.3/4 p)".split(".")[1].split()[0]
# Out:
# '3/4'

# %%
"2022.3/4 p)".split(".")[1].split()[0].split("/")
# Out:
# ['3', '4']

# %%
"2022.3/4 p)".split(".")[1].split()[0].split("/")[0]
# Out:
# '3'

# %%
df["기간"].map(lambda x : int(x.split(".")[1].split()[0].split("/")[0]))
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10345    3
# 10346    3
# 10347    3
# 10348    3
# 10349    3
# Name: 기간, Length: 10350, dtype: int64

# %%
# 분기 컬럼 만들기

df["분기"] = df["기간"].map(lambda x : int(x.split(".")[1].split()[0].split("/")[0]))
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간     백만원  분기    연도
# 0      합계          합계       계  2017.1/4  839944   1  2017
# 1      합계          합계     면세점  2017.1/4  673803   1  2017
# 2      합계          합계  면세점 이외  2017.1/4  166141   1  2017
# 3      합계  컴퓨터 및 주변기기       계  2017.1/4    2645   1  2017
# 4      합계  컴퓨터 및 주변기기     면세점  2017.1/4       5   1  2017

# %% [markdown]
# #### **5.2 Changing the data type to express the amount as numeric data**
# [금액을 수치데이터로 표현하기 위해 데이터 타입 변경하기]

# %%
# _ 문자를 결측치로 변경하고 float 타입으로 변경하기

df["백만원"]
# Out:
# 0        839944
# 1        673803
# 2        166141
# 3          2645
# 4             5
#           ...
# 10345         0
# 10346        83
# 10347       288
# 10348         0
# 10349       288
# Name: 백만원, Length: 10350, dtype: int64

# %%
# 위에는 나오지 않지만 중간에 "-"표시가 뜨는데 이것은 자료없음을 의미함
# "-"표시를 numpy 를 이용해 결측치(np.nan)로 바꾼다

import numpy as np

df["백만원"].replace("-", np.nan)
# Out:
# 0        839944
# 1        673803
# 2        166141
# 3          2645
# 4             5
#           ...
# 10345         0
# 10346        83
# 10347       288
# 10348         0
# 10349       288
# Name: 백만원, Length: 10350, dtype: int64

# %%
# NaN이라는 결측치 데이터가 float 타입이기때문에 dtype을 float으로 바꿔주기

df["백만원"].replace("-", np.nan).astype(float)
# Out:
# 0        839944.0
# 1        673803.0
# 2        166141.0
# 3          2645.0
# 4             5.0
#            ...
# 10345         0.0
# 10346        83.0
# 10347       288.0
# 10348         0.0
# 10349       288.0
# Name: 백만원, Length: 10350, dtype: float64

# %%
df["백만원"] = df["백만원"].replace("-", np.nan).astype(float)
df["백만원"]
# Out:
# 0        839944.0
# 1        673803.0
# 2        166141.0
# 3          2645.0
# 4             5.0
#            ...
# 10345         0.0
# 10346        83.0
# 10347       288.0
# 10348         0.0
# 10349       288.0
# Name: 백만원, Length: 10350, dtype: float64

# %%
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간       백만원  분기    연도
# 0      합계          합계       계  2017.1/4  839944.0   1  2017
# 1      합계          합계     면세점  2017.1/4  673803.0   1  2017
# 2      합계          합계  면세점 이외  2017.1/4  166141.0   1  2017
# 3      합계  컴퓨터 및 주변기기       계  2017.1/4    2645.0   1  2017
# 4      합계  컴퓨터 및 주변기기     면세점  2017.1/4       5.0   1  2017

# %% [markdown]
# #### **5.3 Remove unnecessary data**
# [필요없는 데이터 제거하기]

# %%
# 합계 데이터는 따로 구할 수 있기 때문에 전체 데이터에서 제거합니다.

df
# Out:
#       국가(대륙)별          상품군별   판매유형별           기간       백만원  분기    연도
# 0          합계            합계       계     2017.1/4  839944.0   1  2017
# 1          합계            합계     면세점     2017.1/4  673803.0   1  2017
# 2          합계            합계  면세점 이외     2017.1/4  166141.0   1  2017
# 3          합계    컴퓨터 및 주변기기       계     2017.1/4    2645.0   1  2017
# 4          합계    컴퓨터 및 주변기기     면세점     2017.1/4       5.0   1  2017
# ...       ...           ...     ...          ...       ...  ..   ...
# 10345      기타  생활용품 및 자동차용품     면세점  2022.3/4 p)       0.0   3  2022
# 10346      기타  생활용품 및 자동차용품  면세점 이외  2022.3/4 p)      83.0   3  2022
# 10347      기타           기 타       계  2022.3/4 p)     288.0   3  2022
# 10348      기타           기 타     면세점  2022.3/4 p)       0.0   3  2022
# 10349      기타           기 타  면세점 이외  2022.3/4 p)     288.0   3  2022
#
# [10350 rows x 7 columns]

# %%
df[(df["국가(대륙)별"] == "합계") | (df["상품군별"] == "합계")]

# 이 데이터("합계")는 사용하지 않을 것이므로 위의 조건의 반대(대우)를 사용함
# Out:
#       국가(대륙)별        상품군별   판매유형별           기간       백만원  분기    연도
# 0          합계          합계       계     2017.1/4  839944.0   1  2017
# 1          합계          합계     면세점     2017.1/4  673803.0   1  2017
# 2          합계          합계  면세점 이외     2017.1/4  166141.0   1  2017
# 3          합계  컴퓨터 및 주변기기       계     2017.1/4    2645.0   1  2017
# 4          합계  컴퓨터 및 주변기기     면세점     2017.1/4       5.0   1  2017
# ...       ...         ...     ...          ...       ...  ..   ...
# 10261     대양주          합계     면세점  2022.3/4 p)       2.0   3  2022
# 10262     대양주          합계  면세점 이외  2022.3/4 p)    3229.0   3  2022
# 10305      기타          합계       계  2022.3/4 p)    3888.0   3  2022
# 10306      기타          합계     면세점  2022.3/4 p)     105.0   3  2022
# 10307      기타          합계  면세점 이외  2022.3/4 p)    3783.0   3  2022
#
# [1656 rows x 7 columns]

# %%
df[(df["국가(대륙)별"] != "합계") & (df["상품군별"] != "합계")]
# Out:
#       국가(대륙)별          상품군별   판매유형별           기간     백만원  분기    연도
# 48         미국    컴퓨터 및 주변기기       계     2017.1/4  1081.0   1  2017
# 49         미국    컴퓨터 및 주변기기     면세점     2017.1/4     0.0   1  2017
# 50         미국    컴퓨터 및 주변기기  면세점 이외     2017.1/4  1081.0   1  2017
# 51         미국    가전·전자·통신기기       계     2017.1/4  2895.0   1  2017
# 52         미국    가전·전자·통신기기     면세점     2017.1/4    18.0   1  2017
# ...       ...           ...     ...          ...     ...  ..   ...
# 10345      기타  생활용품 및 자동차용품     면세점  2022.3/4 p)     0.0   3  2022
# 10346      기타  생활용품 및 자동차용품  면세점 이외  2022.3/4 p)    83.0   3  2022
# 10347      기타           기 타       계  2022.3/4 p)   288.0   3  2022
# 10348      기타           기 타     면세점  2022.3/4 p)     0.0   3  2022
# 10349      기타           기 타  면세점 이외  2022.3/4 p)   288.0   3  2022
#
# [8694 rows x 7 columns]

# %%
# 위의 데이터를 다시한번 df에 저장하고 copy()함
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10350 entries, 0 to 10349
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  10350 non-null  object
#  1   상품군별     10350 non-null  object
#  2   판매유형별    10350 non-null  object
#  3   기간       10350 non-null  object
#  4   백만원      10350 non-null  float64
#  5   분기       10350 non-null  int64
#  6   연도       10350 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 566.1+ KB

# %%
df = df[(df["국가(대륙)별"] != "합계") & (df["상품군별"] != "합계")].copy()
df
# Out:
#       국가(대륙)별          상품군별   판매유형별           기간     백만원  분기    연도
# 48         미국    컴퓨터 및 주변기기       계     2017.1/4  1081.0   1  2017
# 49         미국    컴퓨터 및 주변기기     면세점     2017.1/4     0.0   1  2017
# 50         미국    컴퓨터 및 주변기기  면세점 이외     2017.1/4  1081.0   1  2017
# 51         미국    가전·전자·통신기기       계     2017.1/4  2895.0   1  2017
# 52         미국    가전·전자·통신기기     면세점     2017.1/4    18.0   1  2017
# ...       ...           ...     ...          ...     ...  ..   ...
# 10345      기타  생활용품 및 자동차용품     면세점  2022.3/4 p)     0.0   3  2022
# 10346      기타  생활용품 및 자동차용품  면세점 이외  2022.3/4 p)    83.0   3  2022
# 10347      기타           기 타       계  2022.3/4 p)   288.0   3  2022
# 10348      기타           기 타     면세점  2022.3/4 p)     0.0   3  2022
# 10349      기타           기 타  면세점 이외  2022.3/4 p)   288.0   3  2022
#
# [8694 rows x 7 columns]

# %%
# info로 정보 보기

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8694 entries, 48 to 10349
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  8694 non-null   object
#  1   상품군별     8694 non-null   object
#  2   판매유형별    8694 non-null   object
#  3   기간       8694 non-null   object
#  4   백만원      8694 non-null   float64
#  5   분기       8694 non-null   int64
#  6   연도       8694 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 543.4+ KB

# %%
# 결측치 보기

df.isnull().sum()
# Out:
# 국가(대륙)별    0
# 상품군별       0
# 판매유형별      0
# 기간         0
# 백만원        0
# 분기         0
# 연도         0
# dtype: int64

# %% [markdown]
# ***

# %%
# 5.5강 전체 상품군별 데이터로 연도별 증가추세 시각화 하기 (10:29)

# %% [markdown]
# ### **6. K-Beauty visualization**
# [K-Beauty 시각화]

# %% [markdown]
# #### **6.1 Total product group sales**
# [전체 상품군 판매액]

# %%
# 판매유형별 데이터는 일부 기간에는 "계"만 존재하기 때문에
# 판매유형별 == "계"데이터만 가져와서 봐야지
# 평균 값을 구하는 그래프에서 올바른 값을 표현할 수 있습니다.

df[df["판매유형별"] == "계"]
# Out:
#       국가(대륙)별          상품군별 판매유형별           기간     백만원  분기    연도
# 48         미국    컴퓨터 및 주변기기     계     2017.1/4  1081.0   1  2017
# 51         미국    가전·전자·통신기기     계     2017.1/4  2895.0   1  2017
# 54         미국         소프트웨어     계     2017.1/4    68.0   1  2017
# 57         미국           서 적     계     2017.1/4  1969.0   1  2017
# 60         미국         사무·문구     계     2017.1/4    69.0   1  2017
# ...       ...           ...   ...          ...     ...  ..   ...
# 10335      기타       아동·유아용품     계  2022.3/4 p)   497.0   3  2022
# 10338      기타         음·식료품     계  2022.3/4 p)    20.0   3  2022
# 10341      기타         농축수산물     계  2022.3/4 p)     0.0   3  2022
# 10344      기타  생활용품 및 자동차용품     계  2022.3/4 p)    83.0   3  2022
# 10347      기타           기 타     계  2022.3/4 p)   288.0   3  2022
#
# [2898 rows x 7 columns]

# %%
df_total = df[df["판매유형별"] == "계"].copy()
df.head()
# Out:
#    국가(대륙)별        상품군별   판매유형별        기간     백만원  분기    연도
# 48      미국  컴퓨터 및 주변기기       계  2017.1/4  1081.0   1  2017
# 49      미국  컴퓨터 및 주변기기     면세점  2017.1/4     0.0   1  2017
# 50      미국  컴퓨터 및 주변기기  면세점 이외  2017.1/4  1081.0   1  2017
# 51      미국  가전·전자·통신기기       계  2017.1/4  2895.0   1  2017
# 52      미국  가전·전자·통신기기     면세점  2017.1/4    18.0   1  2017

# %%
# 연도, 판매액 lineplot으로 그리기

sns.lineplot(data=df_total, x="연도", y="백만원")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %% [markdown]
# - legend 를 그래프의 밖에 그리기 : [Move legend outside figure in seaborn tsplot [duplicate]](https://stackoverflow.com/questions/30490740/move-legend-outside-figure-in-seaborn-tsplot)

# %%
# 연도, 판매액 lineplot으로 그리고 상품군별로 다른 색상으로 표시하기

sns.lineplot(data=df_total, x="연도", y="백만원", hue="상품군별")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %%
# legend 밖에 표시(위의 사이트참고)
# # Put the legend out of the figure
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

sns.lineplot(data=df_total, x="연도", y="백만원", hue="상품군별")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
# 위에 그린 그래프를 자세히 보기 위해 서브플롯으로 표시하기

sns.relplot(data=df_total, x="연도", y="백만원", hue="상품군별")

# %%
# col 옵션과 col_wrap옵션(한줄에 몇개를 표현할 것인가)으로 자세히 표시

sns.relplot(data=df_total, x="연도", y="백만원", hue="상품군별",
            kind = "line", col="상품군별", col_wrap=4_)
# Out:
#   File "C:\Users\YUNI\AppData\Local\Temp\ipykernel_11692\2584284219.py", line 4
#     kind = "line", col="상품군별", col_wrap=4_)
#                                          ^
# SyntaxError: invalid decimal literal

# %%
# isin 을 사용해 화장품만 제외를 하고 df_sub 이라는 변수에 담습니다.

df_total[df_total["상품군별"].isin(["화장품"])]

# %%
#위의 값은 "화장품"만 이르모 "~"표시로 화장품만을 제외한다

df_total[~df_total["상품군별"].isin(["화장품"])]

# %%
# "화장품"만 뺀 값을 df_sub에 담기

df_sub = df_total[~df_total["상품군별"].isin(["화장품"])].copy()

# %%
# 연도별 판매액을 상품군별로 relplot 을 활용해 서브플롯으로 그려보기

sns.relplot(data=df_sub, x="연도", y="백만원",
            hue="상품군별", col="상품군별", col_wrap=4, kind="line")

# %%
# "화장품" 뿐만 아니라 "의류 및 패션 관련상품"도 제외하기

df_sub1 = df_total[~df_total["상품군별"].isin(["화장품", "의류 및 패션 관련상품"])].copy()

# %%
sns.relplot(data=df_sub1, x="연도", y="백만원",
            hue="상품군별", col="상품군별", col_wrap=4, kind="line")

# %% [markdown]
# ***

# %%
# 5.6강 - 화장품 온라인 해외 직접 판매액 시각화 (12:28)

# %% [markdown]
# #### **6.2 Online shopping overseas direct sales of cosmetics**
# [화장품의 온라인쇼핑 해외직접판매액]

# %%
# df_cosmetic 이라는 변수에 상품군별이 화장품인 데이터만 가져오기

df_cosmetic = df_total[df_total["상품군별"] == "화장품"].copy()
df_cosmetic.head()
# Out:
#         국가(대륙)별 상품군별 판매유형별        기간       백만원  분기    연도
# 72           미국  화장품     계  2017.1/4   15522.0   1  2017
# 117          중국  화장품     계  2017.1/4  603133.0   1  2017
# 162          일본  화장품     계  2017.1/4    5052.0   1  2017
# 207  아세안(ASEAN)  화장품     계  2017.1/4   17878.0   1  2017
# 252    유럽연합(EU)  화장품     계  2017.1/4    2506.0   1  2017

# %%
df_cosmetic["상품군별"].unique()

# "상품군별"에 "화장품"만 들어가 있는 것을 볼 수 있음
# Out:
# array(['화장품'], dtype=object)

# %%
# 연도와 판매액을 lineplot 으로 그리고 분기별로 다른 색상으로 표현해 보기

plt.figure(figsize=(10,4))
sns.lineplot(data=df_cosmetic, x="연도", y="백만원", hue="분기")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %%
df_cosmetic.head()
# Out:
#         국가(대륙)별 상품군별 판매유형별        기간       백만원  분기    연도
# 72           미국  화장품     계  2017.1/4   15522.0   1  2017
# 117          중국  화장품     계  2017.1/4  603133.0   1  2017
# 162          일본  화장품     계  2017.1/4    5052.0   1  2017
# 207  아세안(ASEAN)  화장품     계  2017.1/4   17878.0   1  2017
# 252    유럽연합(EU)  화장품     계  2017.1/4    2506.0   1  2017

# %%
# 화장품 판매액에 대한 기간별 금액 데이터 시각화 하기

plt.figure(figsize=(10,4))
plt.xticks(rotation=30)

sns.lineplot(data=df_cosmetic, x="기간", y="백만원")
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
# 화장품 판매액에 대한 기간별 금액 데이터를 시각화하고 "국가(대륙)별"로 다른 색상으로 표시하기

plt.figure(figsize=(10,4))
plt.xticks(rotation=30)

# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.lineplot(data=df_cosmetic, x="기간", y="백만원", hue="국가(대륙)별")
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
# 중국 제외한 다른 국가들도 자세히 보고 싶을 때,

plt.figure(figsize=(12,4))
plt.xticks(rotation=30)

sns.lineplot(data=df_cosmetic[df_cosmetic["국가(대륙)별"] != "중국"],
             x="기간", y="백만원", hue="국가(대륙)별")
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
# 화장품 판매액에 대한 기간별 금액 데이터를 시각화 하고 
#"판매유형별"로 다른 색상으로 표시하기

# "계" 제외하고 보기
df[df["판매유형별"] != "계"].copy()
# Out:
#       국가(대륙)별          상품군별   판매유형별           기간     백만원  분기    연도
# 49         미국    컴퓨터 및 주변기기     면세점     2017.1/4     0.0   1  2017
# 50         미국    컴퓨터 및 주변기기  면세점 이외     2017.1/4  1081.0   1  2017
# 52         미국    가전·전자·통신기기     면세점     2017.1/4    18.0   1  2017
# 53         미국    가전·전자·통신기기  면세점 이외     2017.1/4  2877.0   1  2017
# 55         미국         소프트웨어     면세점     2017.1/4     0.0   1  2017
# ...       ...           ...     ...          ...     ...  ..   ...
# 10343      기타         농축수산물  면세점 이외  2022.3/4 p)     0.0   3  2022
# 10345      기타  생활용품 및 자동차용품     면세점  2022.3/4 p)     0.0   3  2022
# 10346      기타  생활용품 및 자동차용품  면세점 이외  2022.3/4 p)    83.0   3  2022
# 10348      기타           기 타     면세점  2022.3/4 p)     0.0   3  2022
# 10349      기타           기 타  면세점 이외  2022.3/4 p)   288.0   3  2022
#
# [5796 rows x 7 columns]

# %%
# 위의 결과를 df_sub2 변수에 담아서 시각화

df_sub2 = df[df["판매유형별"] != "계"].copy()

sns.lineplot(data = df_sub2, x="기간", y="백만원")

#밑에 글씨 깨짐
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
plt.figure(figsize=(12,4))
plt.xticks(rotation=30)

df_sub2 = df[df["판매유형별"] != "계"].copy()
sns.lineplot(data = df_sub2, x="기간", y="백만원", hue="판매유형별")

# 면세점은 온라인면세점을 의미함
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
# 위에서 "면세점 이외"를 더 자세히 보고 싶으면
# "면세점"을 제외하고 표시함
# ci=None 으로 그림자 빼보기

plt.figure(figsize=(12,4))
plt.xticks(rotation=30)

df_sub2 = df[(df["판매유형별"] != "계") & (df["판매유형별"] != "면세점")].copy()
sns.lineplot(data = df_sub2, x="기간", y="백만원", hue="판매유형별", ci=None)
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
# 면세점 이외에는 온라인쇼핑몰이 많이 있음
# 꾸준히 증가하다가 2020년 코로나사태 이후로 점점 줄어듬

# %% [markdown]
# ***

# %%
# 5.7강- 패션 의류 온라인 해외 직접 판매액 시각화 (06:00)

# %% [markdown]
# #### **6.3 Clothing and fashion-related products Online shopping Overseas direct sales**
# [의류 및 패션관련 상품 온라인쇼핑 해외직접판매]

# %%
# df_fashion 이라는 변수에 의류 데이터만 가져와 따로 담아주기
df_fashion = df[df["상품군별"] == "의류 및 패션 관련상품"].copy()
df_fashion.head()
# Out:
#     국가(대륙)별          상품군별   판매유형별        기간      백만원  분기    연도
# 66       미국  의류 및 패션 관련상품       계  2017.1/4  14746.0   1  2017
# 67       미국  의류 및 패션 관련상품     면세점  2017.1/4     98.0   1  2017
# 68       미국  의류 및 패션 관련상품  면세점 이외  2017.1/4  14648.0   1  2017
# 111      중국  의류 및 패션 관련상품       계  2017.1/4  58988.0   1  2017
# 112      중국  의류 및 패션 관련상품     면세점  2017.1/4  31623.0   1  2017

# %%
# "의류 및 패션관련 상품" 판매액에 대한 기간별 금액 데이터를 시각화하고
# "국가(대륙)별"로 다른 색상으로 표시하기

plt.figure(figsize=(15,4))
plt.xticks(rotation=30)

sns.lineplot(data = df_fashion, x="기간", y="백만원", hue="국가(대륙)별")
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %%
# "의류 및 패션관련 상품" 판매액에 대한 기간별 금액 데이터를 시각화하고
# "판매유형별"로 다른 색상으로 표시하기

plt.figure(figsize=(15,4))
plt.xticks(rotation=30)

sns.lineplot(data = df_fashion, x="기간", y="백만원", hue="판매유형별", ci=None)
# Out:
# <AxesSubplot:xlabel='기간', ylabel='백만원'>

# %% [markdown]
# ***

# %%
# 5.8강 - 데이터 pivot table로 집계하고 heatmap 으로 표현하기 (07:14)

# %% [markdown]
# #### **6.4 Aggregating data**
# [데이터 집계하기]

# %%
# 피봇테이블로 "국가(대륙)별", "연도"별 합계 금액을 표 형태로 구하기

df_fashion.pivot_table?
# Out:
# Signature:
# df_fashion.pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc='mean',
#     fill_value=None,
#     margins=False,
#     dropna=True,
#     margins_name='All',
#     observed=False,
#     sort=True,
# ) -> 'DataFrame'
# Docstring:
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects
# (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# ----------
# values : column to aggregate, optional
# index : column, Grouper, array, or list of the previous
#     If an array is passed, it must be the same length as the data. The
#     list can contain any of the other types (except list).
#     Keys to group by on the pivot table index.  If an array is passed,
#     it is being used as the same manner as column values.
# columns : column, Grouper, array, or list of the previous
# ...

# %%
df_fashion.pivot_table(index="국가(대륙)별", columns="연도", values="백만원")

# 결과로 나오는 값은 평균값. why?
# default가 aggfunc = 'mean' 으로 지정되어 있기 때문
# Out:
# 연도                  2017          2018          2019          2020  \
# 국가(대륙)별
# 기타           2198.666667   3983.500000   1079.166667   1301.166667
# 대양주           452.666667    454.166667    414.833333    624.833333
# 미국           8606.333333   7979.166667   9256.000000  13701.166667
# 아세안(ASEAN)   4049.500000   3844.666667   5207.833333   6556.500000
# 유럽연합(EU)      681.833333    685.666667    615.666667    854.666667
# 일본          15088.500000  22800.000000  22439.500000  19921.833333
# 중국          38055.000000  48141.333333  55044.500000  17724.333333
# 중남미           128.666667     96.000000     90.666667    102.333333
# 중동            134.666667    146.500000    158.500000    296.000000
#
# 연도                  2021          2022
# 국가(대륙)별
# 기타           1429.666667   1208.888889
# 대양주          1003.833333   1141.333333
# 미국          16786.833333  14507.555556
# 아세안(ASEAN)   5258.166667   5262.444444
# 유럽연합(EU)     1037.500000   1262.888889
# ...

# %%
#  평균 금액이 아닌 "합계"로 구하기  

df_fashion.pivot_table(index="국가(대륙)별", columns="연도",
                       values="백만원", aggfunc ="sum")
# Out:
# 연도              2017      2018      2019      2020      2021      2022
# 국가(대륙)별
# 기타           26384.0   47802.0   12950.0   15614.0   17156.0   10880.0
# 대양주           5432.0    5450.0    4978.0    7498.0   12046.0   10272.0
# 미국          103276.0   95750.0  111072.0  164414.0  201442.0  130568.0
# 아세안(ASEAN)   48594.0   46136.0   62494.0   78678.0   63098.0   47362.0
# 유럽연합(EU)      8182.0    8228.0    7388.0   10256.0   12450.0   11366.0
# 일본          181062.0  273600.0  269274.0  239062.0  237934.0  135294.0
# 중국          456660.0  577696.0  660534.0  212692.0  183540.0   69230.0
# 중남미           1544.0    1152.0    1088.0    1228.0    1222.0     300.0
# 중동            1616.0    1758.0    1902.0    3552.0    2924.0    1242.0

# %%
# 확인 

df_fashion.head(2)
# Out:
#    국가(대륙)별          상품군별 판매유형별        기간      백만원  분기    연도
# 66      미국  의류 및 패션 관련상품     계  2017.1/4  14746.0   1  2017
# 67      미국  의류 및 패션 관련상품   면세점  2017.1/4     98.0   1  2017

# %%
# 확인 

df_fashion["판매유형별"].value_counts()
# Out:
# 계         207
# 면세점       207
# 면세점 이외    207
# Name: 판매유형별, dtype: int64

# %%
# 위의 자료는 어느 대륙이 금액이 많고 적은 지 한 눈에 보기 어려우므로
# result 변수에 담에 다음에서 시각화


result = df_fashion.pivot_table(index="국가(대륙)별", columns="연도",
                       values="백만원", aggfunc ="sum")

# %% [markdown]
# #### **6.5 View calculation results visually**
# [연산결과를 시각적으로 보기]

# %%
# 피봇테이블로 구한 결과를 값의 많고 적음에 따라 시각적으로 표현하기

sns.heatmap(result)
# Out:
# <AxesSubplot:xlabel='연도', ylabel='국가(대륙)별'>

# %%
sns.heatmap(result, cmap="Blues") # 값이 클 수록 진하게
# Out:
# <AxesSubplot:xlabel='연도', ylabel='국가(대륙)별'>

# %%
sns.heatmap(result, cmap="Blues_r") # 값이 작을수록 진하게
# Out:
# <AxesSubplot:xlabel='연도', ylabel='국가(대륙)별'>

# %%
# 칸 안에 수치를 표현(annot = True)하고 숫자를 소숫점없이(fmt=".0f") 표현

plt.figure(figsize=(10,6))
sns.heatmap(result, cmap="Blues", annot = True, fmt=".0f")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='국가(대륙)별'>

# %% [markdown]
# ***

# %%
# 5.9강 - 전체상품군별 시각화 (07:41)

# %% [markdown]
# ### **7. Did online shopping overseas direct sales increase by whole product category?**
# [전체 상품군별로 온라인쇼핑 해외직접판매액은 증가했을까?]

# %%
# 위에서 판매유형별 데이터의 "계"만 모은 df_total 변수를 통한 연도별 합계 금액을 시각화 하기

df_total
# Out:
#       국가(대륙)별          상품군별 판매유형별           기간     백만원  분기    연도
# 48         미국    컴퓨터 및 주변기기     계     2017.1/4  1081.0   1  2017
# 51         미국    가전·전자·통신기기     계     2017.1/4  2895.0   1  2017
# 54         미국         소프트웨어     계     2017.1/4    68.0   1  2017
# 57         미국           서 적     계     2017.1/4  1969.0   1  2017
# 60         미국         사무·문구     계     2017.1/4    69.0   1  2017
# ...       ...           ...   ...          ...     ...  ..   ...
# 10335      기타       아동·유아용품     계  2022.3/4 p)   497.0   3  2022
# 10338      기타         음·식료품     계  2022.3/4 p)    20.0   3  2022
# 10341      기타         농축수산물     계  2022.3/4 p)     0.0   3  2022
# 10344      기타  생활용품 및 자동차용품     계  2022.3/4 p)    83.0   3  2022
# 10347      기타           기 타     계  2022.3/4 p)   288.0   3  2022
#
# [2898 rows x 7 columns]

# %%
sns.barplot(data=df_total, x="연도", y="백만원")

# y축 값은 평균을 나타냄 (estimatoy=<fuction at mean...>)
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %%
# 연도별 판매액을 그리고 "국가(대륙)별"로 다른 색상으로 표현하기

sns.barplot(data=df_total, x="연도", y="백만원", hue="국가(대륙)별")

# barplot 으로는 알아보기 어려움
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %%
# lineplot 으로 표현

plt.figure(figsize=(10,4))
sns.lineplot(data=df_total, x="연도", y="백만원", hue="국가(대륙)별")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %% [markdown]
# - legend 를 그래프의 밖에 그리기 : [Move legend outside figure in seaborn tsplot [duplicate]](https://stackoverflow.com/questions/30490740/move-legend-outside-figure-in-seaborn-tsplot)

# %%
# 연도별 판매액을 그리고 "상품군별"로 다른 색상으로 표현하기

plt.figure(figsize=(10,4))
sns.lineplot(data=df_total, x="연도", y="백만원", hue="상품군별")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='백만원'>

# %%
# legend 를 그래프 밖에 그리기

plt.figure(figsize=(10,4))

sns.lineplot(data=df_total, x="연도", y="백만원", hue="상품군별")

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
